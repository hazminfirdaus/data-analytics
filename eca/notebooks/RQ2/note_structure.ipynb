# %% [markdown]
#     1.	EDA → identify relationships (CP, Cramér’s V)
# 	2.	LR (full) → multivariate explanation
# 	3.	LR (subsets) → structure + parsimony
# 	4.	RF → robustness + performance
# 	5.	Comparison → synthesis
#
#
#
# data-analytics/
# │
# ├── data/
# │   ├── osmi-raw.csv
# │   ├── osmi-clean.csv
# │   └── osmi-encoded.csv
# │
# ├── notebooks/
# │   ├── 01_eda_cp_cramers.ipynb
# │   ├── 02_logistic_regression_full.ipynb
# │   ├── 03_lr_subsets.ipynb
# │   ├── 04_random_forest.ipynb
# │   └── 05_model_comparison.ipynb
# │
# ├── results/
# │   ├── eda_cp_single.csv
# │   ├── eda_cp_pairwise.csv
# │   ├── eda_cramers_v.csv
# │   │
# │   ├── lr_full_metrics.json
# │   ├── lr_full_coefficients.csv
# │   │
# │   ├── lr_coefficients_top_predictors.csv
# │   ├── lr_coefficients_workplace.csv
# │   ├── lr_coefficients_demographics.csv
# │   ├── lr_subsets_metrics.json
# │   │
# │   ├── rf_metrics.json
# │   ├── rf_feature_importance.csv
# │   │
# │   └── comparison_metrics.csv
# │
# └── figures/
#     ├── cp_single.png
#     ├── cramers_v.png
#     ├── lr_coefficients.png
#     ├── rf_importance.png
#     └── model_comparison.png
